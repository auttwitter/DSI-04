# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
import pandas as pd 
# Load example dataset
X, y = load_iris(return_X_y=True)

# Define the model and parameter grid
model = RandomForestClassifier(random_state=42)
param_grid = {
    'n_estimators': [10, 50, 100],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5]
}

# Perform GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,  # 5-fold cross-validation
    scoring='accuracy',  # Scoring metric
    return_train_score=True  # Include train scores in results
)
grid_search.fit(X, y)

# Retrieve all scores
results = grid_search.cv_results_
results_df = pd.DataFrame(grid_search.cv_results_)

# # Display results for each combination
# for i in range(len(results['mean_test_score'])):
#     print(f"Parameters: {results['params'][i]}")
#     print(f"Mean Test Score: {results['mean_test_score'][i]}")
#     print(f"Mean Train Score: {results['mean_train_score'][i]}")
#     print()

# %%
results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012675      0.001654         0.003256        0.004973
# 1        0.057099      0.004204         0.000651        0.001302
# 2        0.104026      0.009340         0.006954        0.006262
# 3        0.012168      0.000633         0.000933        0.000194
# 4        0.054821      0.002346         0.002190        0.001199
# 5        0.102220      0.006946         0.003125        0.006250
# 6        0.009452      0.007763         0.000000        0.000000
# 7        0.053961      0.009242         0.000447        0.000894
# 8        0.107239      0.006449         0.003235        0.006471
# 9        0.011253      0.006105         0.000621        0.000508
# 10       0.050171      0.004655         0.002215        0.003156
# 11       0.108913      0.002939         0.004426        0.004599
# 12       0.009369      0.004723         0.000870        0.000448
# 13       0.055003      0.007374         0.000111        0.000221
# 14       0.103772      0.007755         0.003126        0.006252
# 15       0.014109      0.002264         0.002390        0.002986
# 16       0.054831      0.006934         0.001372        0.001156
# 17       0.108843      0.006288         0.003188        0.002787
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 0             None                       2                 10
# 1             None                       2                 50
# 2             None                       2                100
# 3             None                       5                 10
# 4             None                       5                 50
# 5             None                       5                100
# 6                5                       2                 10
# 7                5                       2                 50
# 8                5                       2                100
# 9                5                       5                 10
# 10               5                       5                 50
# 11               5                       5                100
# 12              10                       2                 10
# 13              10                       2                 50
# 14              10                       2                100
# 15              10                       5                 10
# 16              10                       5                 50
# 17              10                       5                100
#
#                                                params  split0_test_score  \
# 0   {'max_depth': None, 'min_samples_split': 2, 'n...           0.966667
# 1   {'max_depth': None, 'min_samples_split': 2, 'n...           0.966667
# 2   {'max_depth': None, 'min_samples_split': 2, 'n...           0.966667
# 3   {'max_depth': None, 'min_samples_split': 5, 'n...           0.966667
# 4   {'max_depth': None, 'min_samples_split': 5, 'n...           0.966667
# 5   {'max_depth': None, 'min_samples_split': 5, 'n...           0.966667
# 6   {'max_depth': 5, 'min_samples_split': 2, 'n_es...           0.966667
# 7   {'max_depth': 5, 'min_samples_split': 2, 'n_es...           0.966667
# 8   {'max_depth': 5, 'min_samples_split': 2, 'n_es...           0.966667
# 9   {'max_depth': 5, 'min_samples_split': 5, 'n_es...           0.966667
# 10  {'max_depth': 5, 'min_samples_split': 5, 'n_es...           0.966667
# 11  {'max_depth': 5, 'min_samples_split': 5, 'n_es...           0.966667
# 12  {'max_depth': 10, 'min_samples_split': 2, 'n_e...           0.966667
# 13  {'max_depth': 10, 'min_samples_split': 2, 'n_e...           0.966667
# 14  {'max_depth': 10, 'min_samples_split': 2, 'n_e...           0.966667
# 15  {'max_depth': 10, 'min_samples_split': 5, 'n_e...           0.966667
# 16  {'max_depth': 10, 'min_samples_split': 5, 'n_e...           0.966667
# 17  {'max_depth': 10, 'min_samples_split': 5, 'n_e...           0.966667
#
#     split1_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0            0.966667  ...         0.966667        0.021082                1
# 1            0.966667  ...         0.966667        0.021082                1
# 2            0.966667  ...         0.966667        0.021082                1
# 3            0.966667  ...         0.960000        0.024944               16
# 4            0.966667  ...         0.966667        0.021082                1
# 5            0.966667  ...         0.966667        0.021082                1
# 6            0.966667  ...         0.966667        0.021082                1
# 7            0.966667  ...         0.966667        0.021082                1
# 8            0.966667  ...         0.966667        0.021082                1
# 9            0.966667  ...         0.960000        0.024944               16
# 10           0.966667  ...         0.966667        0.021082                1
# 11           0.966667  ...         0.966667        0.021082                1
# 12           0.966667  ...         0.966667        0.021082                1
# 13           0.966667  ...         0.966667        0.021082                1
# 14           0.966667  ...         0.966667        0.021082                1
# 15           0.966667  ...         0.960000        0.024944               16
# 16           0.966667  ...         0.966667        0.021082                1
# 17           0.966667  ...         0.966667        0.021082                1
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             1.000000            1.000000            1.000000
# 1             1.000000            1.000000            1.000000
# 2             1.000000            1.000000            1.000000
# 3             0.966667            0.958333            0.991667
# 4             0.975000            0.983333            0.991667
# 5             0.983333            0.991667            0.991667
# 6             1.000000            1.000000            1.000000
# 7             1.000000            1.000000            1.000000
# 8             1.000000            1.000000            1.000000
# 9             0.966667            0.958333            0.991667
# 10            0.975000            0.983333            0.991667
# 11            0.983333            0.983333            0.991667
# 12            1.000000            1.000000            1.000000
# 13            1.000000            1.000000            1.000000
# 14            1.000000            1.000000            1.000000
# 15            0.966667            0.958333            0.991667
# 16            0.975000            0.983333            0.991667
# 17            0.983333            0.991667            0.991667
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0             0.991667            1.000000          0.998333         0.003333
# 1             1.000000            1.000000          1.000000         0.000000
# 2             1.000000            1.000000          1.000000         0.000000
# 3             0.966667            0.975000          0.971667         0.011304
# 4             0.991667            0.983333          0.985000         0.006236
# 5             0.983333            0.983333          0.986667         0.004082
# 6             0.991667            1.000000          0.998333         0.003333
# 7             1.000000            1.000000          1.000000         0.000000
# 8             1.000000            1.000000          1.000000         0.000000
# 9             0.966667            0.975000          0.971667         0.011304
# 10            0.983333            0.975000          0.981667         0.006236
# 11            0.983333            0.975000          0.983333         0.005270
# 12            0.991667            1.000000          0.998333         0.003333
# 13            1.000000            1.000000          1.000000         0.000000
# 14            1.000000            1.000000          1.000000         0.000000
# 15            0.966667            0.975000          0.971667         0.011304
# 16            0.991667            0.983333          0.985000         0.006236
# 17            0.983333            0.983333          0.986667         0.004082
#
# [18 rows x 23 columns]
